# %%
import pathlib
import sys
import os

# Hacky way to get to root package
if "notebooks" in os.getcwd():
    os.chdir("..")

# %%
# %load_ext autoreload
# %autoreload 2
    
import sys
from data_container import load_scouted_data
import pandas as pd
import plotly.express as px
pd.set_option('display.max_columns', None)

# %%
scouted_data = load_scouted_data()
scouted_data

# %%
fig = px.scatter(scouted_data, x="Teleop Fuel", y="Auto Fuel", size="Teleop Fuel Passed", text="Team Number")

fig.update_traces(textposition="middle left")

fig

# %%
team_data = scouted_data[scouted_data["Team Number"] == "3504"]
team_data

# %%
match_14 = scouted_data[scouted_data["Match Number"] == "14"]
match_14
